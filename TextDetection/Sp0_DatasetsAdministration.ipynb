# %%
####################################################################################################################################################
## LIBRARIES:
import glob
import os
import pandas as pd
import numpy as np
import cv2
import shutil
####################################################################################################################################################
## FUNCTIONS:
def visualization(img_path, ann_df):
    
    # The image is loaded:
    imagen = cv2.imread(img_path)
    
    # Each annotation is run through and the verties are extracted to draw it.:
    for idx, row in ann_df.iterrows():
        vert = np.array([[row["x1"], row["y1"]],
                         [row["x2"], row["y2"]],
                         [row["x3"], row["y3"]],
                         [row["x4"], row["y4"]]], dtype=np.int32).reshape((-1, 1, 2))
        cv2.polylines(imagen, [vert], True, (0, 255, 0), 2)
        cv2.putText(image, "1", (vert[0,0,0], vert[0,0,1]), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 1) #Left-upper corner
        cv2.putText(image, "2", (vert[1,0,0,0], vert[1,0,1]), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 1) #Right-up corner
        cv2.putText(image, "3", (vert[2,0,0,0], vert[2,0,1]), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 1) #Lower-right corner
        cv2.putText(image, "4", (vert[3,0,0,0], vert[3,0,1]), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 1) #Left-bottom corner

    # Show the image with the polygons:
    cv2.imshow('Imagen con Polígono', imagen)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    #return
####################################################################################################################################################
## MAIN:
# Determine the working directory and set the path of the final folders:
work_path = os.getcwd() 
ICDAR15_im_path = work_path + chr(92) + "Scene_Text_Datasets" + chr(92) + "Training_Images"
ICDAR15_ann_path = work_path + chr(92) + "Scene_Text_Datasets" + chr(92) + "Training_Annotations"

# Set the path of images and annotations to be modified:
ICDAR13_im_path = work_path + chr(92) + "Challenge2_Training_Task12_Images"
ICDAR13_ann_path = work_path + chr(92) + "Challenge2_Training_Task1_GT"

# Each of the image type files within the ICDAR15 folder is browsed and recompiled:
all_ICDAR15_imgs = []
for ext in ["jpeg", "jpg", "png"]:
    all_ICDAR15_imgs.extend(glob.glob(os.path.join(ICDAR15_im_path, "*.{}".format(ext))))

# Determine which ICDCAR15 file has the highest numbering (the last one) and extract the number:
all_ICDAR15_img = max(all_ICDAR15_imgs, key=lambda x: int(x.split(chr(92))[-1].split(".")[0].split("_")[-1]))
last_num = int(all_ICDAR15_img.split(chr(92))[-1].split(".")[0].split("_")[-1]) + 1

# NOTE : Doing "split(chr(92))[-1]" chooses the last part of the "path", i.e.: "img_xxx.ext" (another option is
# "os.path.basename(...)"). Then divide by the dot to get: "img_xxx". Finally, divide by the trailing slash 
# and choose the last one in the list (-1) which will be the number. To the maximum number you add a "+1" for 
# when you pass the new files. 
    
# Each of the image type files within the ICDAR13 folder is traversed and recompiled:
all_ICDAR13_imgs = []
for ext in ["jpeg", "jpg", "png"]:
    all_ICDAR13_imgs.extend(glob.glob(os.path.join(ICDAR13_im_path, "*.{}".format(ext))))      

# Each ICDAR13 image path is traversed and passed along with its TXT file:
for img in all_ICDAR13_imgs:
    
    # The name of the TXT attached to the selected ICDAR13 image is determined and it is determined if it exists:
    txt_path = os.path.join(ICDAR13_ann_path, "gt_" + os.path.basename(img).split(".")[0] + ".txt")
    if not os.path.exists(txt_path):
        print("The image \"{}\" has no annotations attached and is discarded.".format(os.path.basename(img)))
        continue #Go to the next image
        
    # The annotation file is loaded and the new annotation format is initialised:
    txt_df = pd.read_csv(txt_path, delimiter=" ", names=["left", "top", "right", "bottom", "text"])
    new_txt_df = pd.DataFrame({"x1":[], "y1":[], "x2":[], "y2":[], "x3":[], "y3":[], "x4":[], "y4":[], "text":[]})
    
    # Annotations are generated in ICDAR15 format and saved back to the previous TXT:
    new_txt_df["x1"] = txt_df["left"] #Left-upper corner
    new_txt_df["y1"] = txt_df["top"] #Left-upper corner
    new_txt_df["x2"] = txt_df["right"] #Right-upper corner
    new_txt_df["y2"] = txt_df["top"] #Top-right corner
    new_txt_df["x3"] = txt_df["right"] #Right-bottom corner
    new_txt_df["y3"] = txt_df["bottom"] #Bottom-right corner
    new_txt_df["x4"] = txt_df["left"] #Left-bottom corner
    new_txt_df["y4"] = txt_df["bottom"] #Left-bottom corner
    new_txt_df["text"] = txt_df["text"].astype("str").apply(lambda x: x.replace(",", " "))
    new_txt_df.to_csv(txt_path, sep=",", index=False, header=False)
    #-> visualization(img, new_txt_df) #Can be visualised if desired to check corner orientation
    
    # The extension of the ICDAR13 image to be moved is extracted (strategy already applied):
    ext = img.split(chr(92))[-1].split(".")[-1]
    
    # The new ICDAR13 image/TXT destination path with renaming is generated:
    new_img_ICDAR15_path = os.path.join(ICDAR15_im_path, "img_{}.{}".format(last_num, ext))
    new_ann_ICDAR15_path = os.path.join(ICDAR15_ann_path, "gt_img_{}.txt".format(last_num))
    
    # The image/TXT folder is moved and the numbering is updated:
    shutil.move(img, new_img_ICDAR15_path)
    shutil.move(txt_path, new_ann_ICDAR15_path)
    print("The image \"{}\" has been passed with successfully.".format(img.split(chr(92))[-1]))
    last_num += 1
####################################################################################################################################################
# Out:
# La imagen "102.jpg" se ha pasado con exito.
# La imagen "103.jpg" se ha pasado con exito.
# La imagen "104.jpg" se ha pasado con exito.
# La imagen "105.jpg" se ha pasado con exito.
# La imagen "106.jpg" se ha pasado con exito.
# La imagen "107.jpg" se ha pasado con exito.
# La imagen "108.jpg" se ha pasado con exito.
# La imagen "109.jpg" se ha pasado con exito.
# La imagen "110.jpg" se ha pasado con exito.
# La imagen "111.jpg" se ha pasado con exito.
# La imagen "112.jpg" se ha pasado con exito.
# La imagen "113.jpg" se ha pasado con exito.
# La imagen "114.jpg" se ha pasado con exito.
# La imagen "115.jpg" se ha pasado con exito.
# La imagen "116.jpg" se ha pasado con exito.
# La imagen "117.jpg" se ha pasado con exito.
# La imagen "118.jpg" se ha pasado con exito.
# La imagen "119.jpg" se ha pasado con exito.
# La imagen "120.jpg" se ha pasado con exito.
# La imagen "121.jpg" se ha pasado con exito.
# La imagen "122.jpg" se ha pasado con exito.
# La imagen "123.jpg" se ha pasado con exito.
# La imagen "124.jpg" se ha pasado con exito.
# La imagen "125.jpg" se ha pasado con exito.
# La imagen "126.jpg" se ha pasado con exito.
# La imagen "127.jpg" se ha pasado con exito.
# La imagen "128.jpg" se ha pasado con exito.
# La imagen "129.jpg" se ha pasado con exito.
# La imagen "130.jpg" se ha pasado con exito.
# La imagen "131.jpg" se ha pasado con exito.
# La imagen "132.jpg" se ha pasado con exito.
# La imagen "133.jpg" se ha pasado con exito.
# La imagen "134.jpg" se ha pasado con exito.
# La imagen "135.jpg" se ha pasado con exito.
# La imagen "136.jpg" se ha pasado con exito.
# La imagen "137.jpg" se ha pasado con exito.
# La imagen "138.jpg" se ha pasado con exito.
# La imagen "139.jpg" se ha pasado con exito.
# La imagen "140.jpg" se ha pasado con exito.
# La imagen "141.jpg" se ha pasado con exito.
# La imagen "142.jpg" se ha pasado con exito.
# La imagen "143.jpg" se ha pasado con exito.
# La imagen "144.jpg" se ha pasado con exito.
# La imagen "145.jpg" se ha pasado con exito.
# La imagen "146.jpg" se ha pasado con exito.
# La imagen "147.jpg" se ha pasado con exito.
# La imagen "148.jpg" se ha pasado con exito.
# La imagen "149.jpg" se ha pasado con exito.
# La imagen "150.jpg" se ha pasado con exito.
# La imagen "151.jpg" se ha pasado con exito.
# La imagen "152.jpg" se ha pasado con exito.
# La imagen "153.jpg" se ha pasado con exito.
# La imagen "154.jpg" se ha pasado con exito.
# La imagen "155.jpg" se ha pasado con exito.
# La imagen "156.jpg" se ha pasado con exito.
# La imagen "157.jpg" se ha pasado con exito.
# La imagen "158.jpg" se ha pasado con exito.
# La imagen "159.jpg" se ha pasado con exito.
# La imagen "160.jpg" se ha pasado con exito.
# La imagen "161.jpg" se ha pasado con exito.
# La imagen "162.jpg" se ha pasado con exito.
# La imagen "163.jpg" se ha pasado con exito.
# La imagen "164.jpg" se ha pasado con exito.
# La imagen "165.jpg" se ha pasado con exito.
# La imagen "166.jpg" se ha pasado con exito.
# La imagen "167.jpg" se ha pasado con exito.
# La imagen "168.jpg" se ha pasado con exito.
# La imagen "169.jpg" se ha pasado con exito.
# La imagen "170.jpg" se ha pasado con exito.
# La imagen "171.jpg" se ha pasado con exito.
# La imagen "172.jpg" se ha pasado con exito.
# La imagen "173.jpg" se ha pasado con exito.
# La imagen "174.jpg" se ha pasado con exito.
# La imagen "175.jpg" se ha pasado con exito.
# La imagen "176.jpg" se ha pasado con exito.
# La imagen "177.jpg" se ha pasado con exito.
# La imagen "178.jpg" se ha pasado con exito.
# La imagen "179.jpg" se ha pasado con exito.
# La imagen "180.jpg" se ha pasado con exito.
# La imagen "181.jpg" se ha pasado con exito.
# La imagen "182.jpg" se ha pasado con exito.
# La imagen "183.jpg" se ha pasado con exito.
# La imagen "184.jpg" se ha pasado con exito.
# La imagen "185.jpg" se ha pasado con exito.
# La imagen "186.jpg" se ha pasado con exito.
# La imagen "187.jpg" se ha pasado con exito.
# La imagen "188.jpg" se ha pasado con exito.
# La imagen "189.jpg" se ha pasado con exito.
# La imagen "190.jpg" se ha pasado con exito.
# La imagen "191.jpg" se ha pasado con exito.
# La imagen "192.jpg" se ha pasado con exito.
# La imagen "193.jpg" se ha pasado con exito.
# La imagen "194.jpg" se ha pasado con exito.
# La imagen "195.jpg" se ha pasado con exito.
# La imagen "196.jpg" se ha pasado con exito.
# La imagen "197.jpg" se ha pasado con exito.
# La imagen "198.jpg" se ha pasado con exito.
# La imagen "199.jpg" se ha pasado con exito.
# La imagen "200.jpg" se ha pasado con exito.
# La imagen "201.jpg" se ha pasado con exito.
# La imagen "202.jpg" se ha pasado con exito.
# La imagen "203.jpg" se ha pasado con exito.
# La imagen "204.jpg" se ha pasado con exito.
# La imagen "205.jpg" se ha pasado con exito.
# La imagen "206.jpg" se ha pasado con exito.
# La imagen "207.jpg" se ha pasado con exito.
# La imagen "208.jpg" se ha pasado con exito.
# La imagen "209.jpg" se ha pasado con exito.
# La imagen "210.jpg" se ha pasado con exito.
# La imagen "211.jpg" se ha pasado con exito.
# La imagen "212.jpg" se ha pasado con exito.
# La imagen "213.jpg" se ha pasado con exito.
# La imagen "214.jpg" se ha pasado con exito.
# La imagen "215.jpg" se ha pasado con exito.
# La imagen "216.jpg" se ha pasado con exito.
# La imagen "217.jpg" se ha pasado con exito.
# La imagen "218.jpg" se ha pasado con exito.
# La imagen "219.jpg" se ha pasado con exito.
# La imagen "220.jpg" se ha pasado con exito.
# La imagen "221.jpg" se ha pasado con exito.
# La imagen "222.jpg" se ha pasado con exito.
# La imagen "223.jpg" se ha pasado con exito.
# La imagen "224.jpg" se ha pasado con exito.
# La imagen "225.jpg" se ha pasado con exito.
# La imagen "226.jpg" se ha pasado con exito.
# La imagen "227.jpg" se ha pasado con exito.
# La imagen "228.jpg" se ha pasado con exito.
# La imagen "229.jpg" se ha pasado con exito.
# La imagen "230.jpg" se ha pasado con exito.
# La imagen "231.jpg" se ha pasado con exito.
# La imagen "232.jpg" se ha pasado con exito.
# La imagen "233.jpg" se ha pasado con exito.
# La imagen "234.jpg" se ha pasado con exito.
# La imagen "235.jpg" se ha pasado con exito.
# La imagen "236.jpg" se ha pasado con exito.
# La imagen "237.jpg" se ha pasado con exito.
# La imagen "238.jpg" se ha pasado con exito.
# La imagen "239.jpg" se ha pasado con exito.
# La imagen "240.jpg" se ha pasado con exito.
# La imagen "241.jpg" se ha pasado con exito.
# La imagen "242.jpg" se ha pasado con exito.
# La imagen "243.jpg" se ha pasado con exito.
# La imagen "244.jpg" se ha pasado con exito.
# La imagen "245.jpg" se ha pasado con exito.
# La imagen "246.jpg" se ha pasado con exito.
# La imagen "247.jpg" se ha pasado con exito.
# La imagen "248.jpg" se ha pasado con exito.
# La imagen "249.jpg" se ha pasado con exito.
# La imagen "250.jpg" se ha pasado con exito.
# La imagen "251.jpg" se ha pasado con exito.
# La imagen "252.jpg" se ha pasado con exito.
# La imagen "253.jpg" se ha pasado con exito.
# La imagen "254.jpg" se ha pasado con exito.
# La imagen "255.jpg" se ha pasado con exito.
# La imagen "256.jpg" se ha pasado con exito.
# La imagen "257.jpg" se ha pasado con exito.
# La imagen "258.jpg" se ha pasado con exito.
# La imagen "259.jpg" se ha pasado con exito.
# La imagen "260.jpg" se ha pasado con exito.
# La imagen "261.jpg" se ha pasado con exito.
# La imagen "262.jpg" se ha pasado con exito.
# La imagen "263.jpg" se ha pasado con exito.
# La imagen "264.jpg" se ha pasado con exito.
# La imagen "265.jpg" se ha pasado con exito.
# La imagen "266.jpg" se ha pasado con exito.
# La imagen "267.jpg" se ha pasado con exito.
# La imagen "268.jpg" se ha pasado con exito.
# La imagen "269.jpg" se ha pasado con exito.
# La imagen "270.jpg" se ha pasado con exito.
# La imagen "271.jpg" se ha pasado con exito.
# La imagen "272.jpg" se ha pasado con exito.
# La imagen "273.jpg" se ha pasado con exito.
# La imagen "274.jpg" se ha pasado con exito.
# La imagen "275.jpg" se ha pasado con exito.
# La imagen "276.jpg" se ha pasado con exito.
# La imagen "277.jpg" se ha pasado con exito.
# La imagen "278.jpg" se ha pasado con exito.
# La imagen "279.jpg" se ha pasado con exito.
# La imagen "280.jpg" se ha pasado con exito.
# La imagen "281.jpg" se ha pasado con exito.
# La imagen "282.jpg" se ha pasado con exito.
# La imagen "283.jpg" se ha pasado con exito.
# La imagen "284.jpg" se ha pasado con exito.
# La imagen "285.jpg" se ha pasado con exito.
# La imagen "286.jpg" se ha pasado con exito.
# La imagen "287.jpg" se ha pasado con exito.
# La imagen "288.jpg" se ha pasado con exito.
# La imagen "289.jpg" se ha pasado con exito.
# La imagen "290.jpg" se ha pasado con exito.
# La imagen "291.jpg" se ha pasado con exito.
# La imagen "292.jpg" se ha pasado con exito.
# La imagen "293.jpg" se ha pasado con exito.
# La imagen "294.jpg" se ha pasado con exito.
# La imagen "295.jpg" se ha pasado con exito.
# La imagen "296.jpg" se ha pasado con exito.
# La imagen "297.jpg" se ha pasado con exito.
# La imagen "298.jpg" se ha pasado con exito.
# La imagen "299.jpg" se ha pasado con exito.
# La imagen "300.jpg" se ha pasado con exito.
# La imagen "301.jpg" se ha pasado con exito.
# La imagen "302.jpg" se ha pasado con exito.
# La imagen "303.jpg" se ha pasado con exito.
# La imagen "304.jpg" se ha pasado con exito.
# La imagen "305.jpg" se ha pasado con exito.
# La imagen "306.jpg" se ha pasado con exito.
# La imagen "307.jpg" se ha pasado con exito.
# La imagen "308.jpg" se ha pasado con exito.
# La imagen "309.jpg" se ha pasado con exito.
# La imagen "310.jpg" se ha pasado con exito.
# La imagen "311.jpg" se ha pasado con exito.
# La imagen "312.jpg" se ha pasado con exito.
# La imagen "313.jpg" se ha pasado con exito.
# La imagen "314.jpg" se ha pasado con exito.
# La imagen "315.jpg" se ha pasado con exito.
# La imagen "316.jpg" se ha pasado con exito.
# La imagen "317.jpg" se ha pasado con exito.
# La imagen "318.jpg" se ha pasado con exito.
# La imagen "319.jpg" se ha pasado con exito.
# La imagen "320.jpg" se ha pasado con exito.
# La imagen "321.jpg" se ha pasado con exito.
# La imagen "322.jpg" se ha pasado con exito.
# La imagen "323.jpg" se ha pasado con exito.
# La imagen "324.jpg" se ha pasado con exito.
# La imagen "325.jpg" se ha pasado con exito.
# La imagen "326.jpg" se ha pasado con exito.
# La imagen "327.jpg" se ha pasado con exito.
# La imagen "328.jpg" se ha pasado con exito.
